# %%
pip install git+https://github.com/Princeton-CDH/viapy.git@develop#egg=viapy
# Out:
# ...
#   Cloning https://github.com/Princeton-CDH/viapy.git (to revision develop) to c:\users\yello\appdata\local\temp\pip-install-lz7_evw7\viapy_91be127191d846d398808ee7285c04e9
#   Resolved https://github.com/Princeton-CDH/viapy.git to commit 30a2640654d11e81c86e2e4d21bdac4ffda53a33
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/Princeton-CDH/viapy.git 'C:\Users\yello\AppData\Local\Temp\pip-install-lz7_evw7\viapy_91be127191d846d398808ee7285c04e9'
#   Running command git checkout -b develop --track origin/develop
# ...
